# %%
from ultralytics import YOLO

# %%
import torch
import torchvision
print(torch.__version__)
print(torchvision.__version__)
print(torch.version.cuda)
device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# 2.3.1
# 0.18.1
# None
# Using device: cpu

# %%
model=YOLO("yolov8n.pt")  
model.to(device)
model.train(data='./car/data.yaml', epochs=10, imgsz=640,batch=16,project='runs',   name='train' )
# Out:
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=./car/data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=runs, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynami
# ...

# %%
model.val()
model.save('yolov8_car.pt')
# Out:
# Ultralytics YOLOv8.2.54 🚀 Python-3.11.9 torch-2.3.1 CPU (Apple M2)
# Model summary (fused): 168 layers, 3008768 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/jigyasachouhan/Documents/Learners' Space/LearnersSpace_MachineLearning/Week 2 Assignment/YOLO/car/valid/labels.cache... 160 images, 1 backgrounds, 0 corrupt: 100%|██████████| 160/160 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [01:10<00:00,  7.07s/it]
#                    all        160       1055      0.634      0.719      0.709      0.505
#                   boot         35         39      0.553      0.507      0.593      0.439
#                    car        142        145      0.903      0.979      0.958      0.856
#                   door         50         52      0.734      0.846      0.913      0.645
#           front_bumper         30         30       0.45      0.433      0.492      0.351
# ...

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image
from IPython.display import display

# Function to display an image
confusion_matrix_path = 'runs/train2/confusion_matrix.png'
results_image_path = 'runs/train2/results.png'

def display_image(image_path):
    if os.path.exists(image_path):
        try:
            img = Image.open(image_path)
            display(img)
        except Exception as e:
            print(f"Error loading image {image_path}: {e}")
    else:
        print(f"Image not found: {image_path}")

# Display confusion matrix
display_image(confusion_matrix_path)

# Display results image
display_image(results_image_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3000x2250>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>
